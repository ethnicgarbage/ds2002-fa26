# %% [markdown]
# <a href="https://colab.research.google.com/github/ethnicgarbage/ds2002-fa26/blob/main/notebooks/01-foundations/2026_09_04_%E2%80%94_Submission_Drill_and_Fix_a_Broken_Notebook_%E2%80%94_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DS2002 · Submission Drill and Fix a Broken Notebook
#
# **Lab — 2026-09-04 · Fall 2026**
#
# ---

# %% [markdown]
# ## Lab 02 — Submission Drill and Fix a Broken Notebook
#
# You have inherited a notebook that does not run. This is the most common way you will meet other people's code, so it is worth practicing deliberately.
#
# Seven cells below are broken. Five throw an error, and two return a wrong answer without complaining at all — those are the dangerous ones. Fix all seven, prove your fixes with assertions, then push through the full submit loop.
#
# **Submit in Canvas:** repository link and notebook link.

# %% [markdown]
# ### How to read an error before you fix it
#
# Python's traceback is read **bottom up**. The last line names the exception and the problem; the line above it points at your code.
#
# ```
# Traceback (most recent call last):
#   File "<stdin>", line 2, in <module>
#     print(greeting)
# NameError: name 'greeting' is not defined
# ```
#
# Four exceptions cover most of what you will hit this semester:
#
# | Exception | Usually means |
# |---|---|
# | `NameError` | The variable was never created, or the cell that created it never ran |
# | `TypeError` | You mixed types — text where a number belongs is the classic |
# | `KeyError` | That column or dictionary key does not exist. Check spelling and case |
# | `FileNotFoundError` | The path is wrong for *this* environment |
#
# For each fix below, write one sentence in the markdown cell saying what was actually wrong. "It works now" is not a diagnosis.

# %% [markdown]
# ### Bug 1 — a name that does not exist

# %%
greeting = 'hello world!'

print(greeting)
# Out:
# hello world!

# %% [markdown]
# **What was wrong:** _..._
#
# There was no defined term of what 'greeting' was. As such, I defined greeting as 'hello world!' to ensure that print(greeting) would print.

# %% [markdown]
# ### Bug 2 — text where a number belongs
#
# This should print `30`. Note that `'10' + 20` and `'10' + '20'` fail in different ways — make sure you know which one you are looking at.

# %%
total = 10 + 20
print(total)
# Out:
# 30

# %% [markdown]
# **What was wrong:** _..._
#
# Using '10' or '20' would be incorrect here as it would make those terms a string. Instead, we want it to actually add up 10 and 20 as if they were numbers. I deleted the apostrophe to fix this.

# %% [markdown]
# ### Bug 3 — off the end of a list

# %%
items = ['burger', 'poncho', 'hat']

print(items[-1])
# Out:
# hat

# %% [markdown]
# **What was wrong:** _..._
#
# In a list, the number on the items begin with 0, so in this case: burger would be the '0' item, poncho would be '1', and hat would be '2'. However, as we always want the last item in the list, we need to view it as what value of items[] would bring about the last item every single time. So to fix this, I changed print(items[3]) to print(items[-1]). '-1' will always bring the last tiem, so we should use this value.

# %% [markdown]
# ### Bug 4 — no error, wrong answer
#
# This is supposed to be the average. It prints a number, and the number is wrong.

# %%
nums = [2, 4, 6, 8]
average = sum(nums) / len(nums)
print('average:', average)
# Out:
# average: 5.0

# %% [markdown]
# **What was wrong:** _..._
#
# Here, what was wrong is that the sum of the numbers were divided by 2. There are 4 numbers in this list, so we should divide this by 4 instead of 2. To ensure that this returns the correct value every single time, we should also divide the sum(nums) by len(nums). len(nums) will count the amount of things in the nums list to divide and find the average every single time.

# %% [markdown]
# ### Bug 5 — a table that cannot exist

# %%
import pandas as pd

df = pd.DataFrame({'item': ['a', 'b'], 'price': [1, 2]})
print(df)
# Out:
#   item  price
# 0    a      1
# 1    b      2

# %% [markdown]
# **What was wrong:** _..._
#
# In this data frame, there were  3 prices but only 2 items. To fix this, I could either remove one of the numbers in prices or add an item. I added item 'c' to make that the dataframe worked.
#
# EDIT: This was changed to fix with the assertions that are seen later on so that item and price have a df of 2.

# %% [markdown]
# ### Bug 6 — the answer changes when you re-run it
#
# Run the next cell three times and watch the total move. Then fix it using what you built Wednesday: leave the source data alone and derive a new column from it. Your fix must give the same total on every run.

# %%
sales = pd.DataFrame({
    'game': ['NC State', 'Louisville'],
    'units': [1450, 1610],
})

# TODO: rewrite these two lines so re-running cannot change the answer

# %%
work = sales.copy()

work['units_with_fee'] = work['units'] * 1.05
print('total units:', round(work['units_with_fee'].sum(), 2))
# Out:
# total units: 3213.0

# %%
# Proof — this must print the same number three times
for attempt in range(3):
  work = sales.copy()
  work['units_with_fee'] = work['units'] * 1.05
  print('total units:', round(work['units_with_fee'].sum(), 2))
  # TODO: rebuild from the raw values and print your total
  pass
# Out:
# total units: 3213.0
# total units: 3213.0
# total units: 3213.0

# %% [markdown]
# **What was wrong:** _..._
#
# What was wrong with this code was that as sales['units'] would constantly update with a new number (the previous one * 1.05), it would consistently loop and change its number every single time. I first ensured that sales would be copied (work = sales.copy()) to ensure data integrity of the original data so that it would not be overwritten. Following this, I created 'units_with_fee' to represent the new total units after units were multiplied by 1.05. Doing so ensures that units are not manipulated after rerunning the file multiple times.

# %% [markdown]
# ### Bug 7 — a path from someone else's laptop
#
# This notebook was written on a machine you do not have. Fix it with the pattern from Wednesday's studio: look for the file, and fall back to the inline sample so the notebook still runs for whoever opens it next.

# %%
import os
from io import StringIO

SAMPLE = '''game,units\nNC State,1450\nLouisville,1610\n'''

def read_csv(filename, sample=SAMPLE):
  if os.path.exists(filename):
    print('Reading from file:', filename)
    return pd.read_csv(filename)

  else:
    print("File not found, using sample data.")
    return pd.read_csv(StringIO(sample))

  pass

# TODO: replace this with a lookup + fallback that works anywhere
orders = read_csv('gameday_orders.csv')
orders
# Out:
# File not found, using sample data.
#          game  units
# 0    NC State   1450
# 1  Louisville   1610

# %% [markdown]
# **What was wrong:** _..._
#
# The way the old code worked was to look at a path specific to the person's studio. To change this into one that works more universally, I built it out using the code from the lab, where it will try to look up the location for the filename, and if it was not able to, then it will fall back to the sample dataset that is in the code.

# %% [markdown]
# ### Part 8 — prove the fixes
#
# Assertions are how you state what must be true. If one fails, the notebook stops and tells you which claim broke — much better than scrolling for a wrong number.
#
# **TODO:** uncomment each line and make them all pass.

# %%
assert isinstance(greeting, str) and greeting != ''
assert total == 30
assert items[-1] == 'hat'
assert average == 5
assert len(df) == 2
assert len(orders) >= 2
print('All checks passed.')
# Out:
# All checks passed.

# %% [markdown]
# **What was wrong:** _..._
#
# In the old code, there was an initial assertion error at assert len(df) == 3. To combat this, I looked at the variables that the assertions were checking. Namely, greeting, total, items, average, df, and orders.
#
# I was not entirely sure if I should be changing the variables themselves or the assertions to ensure that all checks passed. I decided on making it so that the assertions passed. To do this, I changed the dataframe so that len(df) would be 2, if I wanted to do it the other way around, I would have kept the dataframe that I changed and changed len(df) to be equal to 3.

# %% [markdown]
# ### Part 9 — the submit drill
#
# This is the part that is actually being graded on process. Do it in order.
#
# 1. **Restart the kernel and Run All.** Zero errors, top to bottom.
# 2. Download the notebook and put it in your repo under `notebooks/01-foundations/`, named `2026-09-04 — Submission Drill and Fix a Broken Notebook — Lab.ipynb`.
# 3. Commit with a message that says what you did, then push.
# 4. Confirm on github.com that the file is there and opens.
# 5. Fill in the cell below and submit both links in Canvas.
#
# **TODO:** fill in the four values and make the check pass.

# %%
import re

repo_url = 'https://github.com/ethnicgarbage/ds2002-fa26'
commit_sha = 'TODO: short hash of the commit with this notebook in it'
notebook_link = 'https://colab.research.google.com/github/jasontpv/DS2002FA26/blob/main/notebooks/01-foundations/2026-09-04%20%E2%80%94%20Submission%20Drill%20and%20Fix%20a%20Broken%20Notebook%20%E2%80%94%20Lab.ipynb#scrollTo=XlzEZ-fHlhuS'
ran_restart_and_run_all = False   # TODO: set True after you actually do it

checks = {
    'repo URL is a github.com URL':
        repo_url.startswith('https://github.com/')
        and repo_url.count('/') >= 4,
    'commit hash looks like a hash':
        bool(re.fullmatch(r'[0-9a-f]{7,40}', commit_sha.strip())),
    'notebook link filled in':
        notebook_link.startswith('http'),
    'restarted and ran all':
        ran_restart_and_run_all is True,
}

for label, passed in checks.items():
    print('PASS' if passed else 'FAIL', '-', label)

print()
print('Ready to submit:', all(checks.values()))
# Out:
# PASS - repo URL is a github.com URL
# FAIL - commit hash looks like a hash
# PASS - notebook link filled in
# FAIL - restarted and ran all
#
# Ready to submit: False

# %% [markdown]
# ### Write-up
#
# Bugs 4 and 6 did not raise an error. In a few sentences: how would you catch that class of bug in a project where you do not already know the right answer? Name something concrete you could add to a notebook.

# %% [markdown]
# _your answer here_

# %% [markdown]
# ### Stretch
#
# Write a `check_orders(df)` function that raises a clear error if the frame is missing either expected column, has zero rows, or contains a negative value in `units`. Then call it on `orders`. This is the shape of validation you will want in both projects.

# %%
# stretch
